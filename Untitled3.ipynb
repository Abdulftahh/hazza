# %% [markdown]
# <a href="https://colab.research.google.com/github/Abdulftahh/hazza/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Download MT-YOLOv6 repository and install requirements
# !git clone https://github.com/meituan/YOLOv6
# %cd YOLOv6
# !pip install -r requirements.txt
# Out:
# Cloning into 'YOLOv6'...
# remote: Enumerating objects: 3838, done.
# remote: Total 3838 (delta 0), reused 0 (delta 0), pack-reused 3838 (from 1)
# Receiving objects: 100% (3838/3838), 43.99 MiB | 13.42 MiB/s, done.
# Resolving deltas: 100% (2298/2298), done.
# /content/YOLOv6
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 65.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   WARNING: Generating metadata for package onnx-simplifier produced metadata for project name onnxsim. Fix your #egg=onnx-simplifier fragments.
# ...
